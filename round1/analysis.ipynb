# %%
# %pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install tensorflow scikit-learn
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting h5py>=3.11.0
#   Using cached h5py-3.13.0-cp310-cp310-win_amd64.whl (3.0 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (1.17.2)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.2.2-py3-none-any.whl (135 kB)
# Requirement already satisfied: setuptools in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (2.1.3)
# Collecting keras>=3.5.0
#   Using cached keras-3.9.2-py3-none-any.whl (1.3 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (3.4.0)
# Collecting tensorboard~=2.19.0
#   Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Collecting ml-dtypes<1.0.0,>=0.5.1
#   Using cached ml_dtypes-0.5.1-cp310-cp310-win_amd64.whl (209 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (0.31.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: packaging in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorflow) (24.2)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting scipy>=1.6.0
#   Using cached scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: optree in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: rich in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-cp310-cp310-win_amd64.whl (102 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Installing collected packages: scipy, ml-dtypes, MarkupSafe, markdown, joblib, idna, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, astunparse, absl-py, werkzeug, scikit-learn, requests, tensorboard, keras, tensorflow
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\akash\\Documents\\Coding Projects\\imc-prosperity-ake-bossers\\myenv\\Lib\\site-packages\\tensorflow-2.19.0.dist-info\\RECORDsfn2lwnf.tmp' -> 'c:\\Users\\akash\\Documents\\Coding Projects\\imc-prosperity-ake-bossers\\myenv\\Lib\\site-packages\\tensorflow-2.19.0.dist-info\\RECORD'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -U prosperity3bt
# Out:
# Requirement already satisfied: prosperity3bt in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (0.5.0)
# Requirement already satisfied: ipython>=8.18.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from prosperity3bt) (8.35.0)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from prosperity3bt) (3.10.16)
# Requirement already satisfied: typer>=0.15.2 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from prosperity3bt) (0.15.2)
# Requirement already satisfied: tqdm>=4.67.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from prosperity3bt) (4.67.1)
# Requirement already satisfied: jsonpickle>=4.0.2 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from prosperity3bt) (4.0.5)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (3.0.50)
# Requirement already satisfied: colorama in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (0.19.2)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (5.14.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (2.19.1)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (4.13.1)
# Requirement already satisfied: matplotlib-inline in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (0.1.7)
# Requirement already satisfied: decorator in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (1.2.2)
# Requirement already satisfied: stack_data in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from ipython>=8.18.1->prosperity3bt) (0.6.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from typer>=0.15.2->prosperity3bt) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from typer>=0.15.2->prosperity3bt) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from typer>=0.15.2->prosperity3bt) (14.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from jedi>=0.16->ipython>=8.18.1->prosperity3bt) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.18.1->prosperity3bt) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from rich>=10.11.0->typer>=0.15.2->prosperity3bt) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from stack_data->ipython>=8.18.1->prosperity3bt) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from stack_data->ipython>=8.18.1->prosperity3bt) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from stack_data->ipython>=8.18.1->prosperity3bt) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.15.2->prosperity3bt) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

data = pd.read_csv('../data/round1/prices_round1.csv', delimiter=';')
data['time'] = data['day'] * 1e6 + data['timestamp']
data.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -2          0  RAINFOREST_RESIN         9996             1       9995.0
# 1   -2          0              KELP         1998            26          NaN
# 2   -2          0         SQUID_INK         1998            26          NaN
# 3   -2        100         SQUID_INK         1999             5       1998.0
# 4   -2        100  RAINFOREST_RESIN        10000             5       9995.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0          25.0          NaN           NaN        10004             1
# 1           NaN          NaN           NaN         2002            26
# 2           NaN          NaN           NaN         2002            26
# 3          26.0          NaN           NaN         2001            20
# 4          20.0          NaN           NaN        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 0      10005.0          25.0          NaN           NaN    10000.0
# 1          NaN           NaN          NaN           NaN     2000.0
# 2          NaN           NaN          NaN           NaN     2000.0
# 3          NaN           NaN          NaN           NaN     2000.0
# 4          NaN           NaN          NaN           NaN    10002.5
#
#    profit_and_loss       time
# 0              0.0 -2000000.0
# 1              0.0 -2000000.0
# 2              0.0 -2000000.0
# 3              0.0 -1999900.0
# 4              0.0 -1999900.0

# %%
data.describe()
# Out:
#                 day      timestamp   bid_price_1  bid_volume_1   bid_price_2  \
# count  90000.000000   90000.000000  90000.000000  90000.000000  35222.000000
# mean      -1.000000  499950.000000   4662.836300     16.903489   7063.033246
# std        0.816501  288676.736916   3771.837725     11.917904   3854.818713
# min       -2.000000       0.000000   1809.000000      0.000000   1811.000000
# 25%       -2.000000  249975.000000   1997.000000      2.000000   2024.000000
# 50%       -1.000000  499950.000000   2030.000000     22.000000   9995.000000
# 75%        0.000000  749925.000000   9995.000000     27.000000   9995.000000
# max        0.000000  999900.000000  10002.000000     40.000000  10000.000000
#
#        bid_volume_2  bid_price_3  bid_volume_3   ask_price_1  ask_volume_1  \
# count  35222.000000  6130.000000   6130.000000  90000.000000  90000.000000
# mean      21.387258  8704.782708     23.465579   4666.886889     16.255733
# std        9.345711  2942.148315      6.715475   3773.763700     11.663429
# min        1.000000  1811.000000      1.000000   1811.000000      1.000000
# 25%       21.000000  9995.000000     22.000000   2000.000000      2.000000
# 50%       24.000000  9995.000000     25.000000   2033.000000     22.000000
# 75%       28.000000  9995.000000     28.000000  10004.000000     27.000000
# max       40.000000  9998.000000     36.000000  10005.000000     32.000000
#
#         ask_price_2  ask_volume_2   ask_price_3  ask_volume_3     mid_price  \
# count  37565.000000  37565.000000   6415.000000   6415.000000  90000.000000
# mean    6754.486676     21.388447   8450.603897     23.351520   4664.861594
# std     3931.217946      9.260910   3166.122578      6.882917   3772.800628
# min     1813.000000      1.000000   1818.000000      1.000000   1810.500000
# 25%     2025.000000     21.000000  10004.000000     22.000000   1998.500000
# 50%    10004.000000     24.000000  10005.000000     25.000000   2031.500000
# 75%    10005.000000     28.000000  10005.000000     28.000000  10000.000000
# max    10005.000000     32.000000  10005.000000     32.000000  10003.500000
#
#        profit_and_loss          time
# count          90000.0  9.000000e+04
# mean               0.0 -5.000500e+05
# std                0.0  8.660302e+05
# min                0.0 -2.000000e+06
# 25%                0.0 -1.250025e+06
# 50%                0.0 -5.000500e+05
# 75%                0.0  2.499250e+05
# max                0.0  9.999000e+05

# %%
RAINFOREST_RESIN = data.loc[data['product'] == 'RAINFOREST_RESIN']
KELP = data.loc[data['product'] == 'KELP']
SQUID_INK = data.loc[data['product'] == 'SQUID_INK']

SQUID_INK.head()
# Out:
#     day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 2    -2          0  SQUID_INK         1998            26          NaN
# 3    -2        100  SQUID_INK         1999             5       1998.0
# 7    -2        200  SQUID_INK         1997            31          NaN
# 11   -2        300  SQUID_INK         1997            27          NaN
# 14   -2        400  SQUID_INK         1996            20          NaN
#
#     bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 2            NaN          NaN           NaN         2002            26
# 3           26.0          NaN           NaN         2001            20
# 7            NaN          NaN           NaN         2000             1
# 11           NaN          NaN           NaN         2000            27
# 14           NaN          NaN           NaN         2000            20
#
#     ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 2           NaN           NaN          NaN           NaN     2000.0
# 3           NaN           NaN          NaN           NaN     2000.0
# 7        2001.0          30.0          NaN           NaN     1998.5
# 11          NaN           NaN          NaN           NaN     1998.5
# 14          NaN           NaN          NaN           NaN     1998.0
#
#     profit_and_loss       time
# 2               0.0 -2000000.0
# 3               0.0 -1999900.0
# 7               0.0 -1999800.0
# 11              0.0 -1999700.0
# 14              0.0 -1999600.0

# %%
import matplotlib.pyplot as plt, seaborn as sns

plt.figure(figsize=(12, 6))
plt.plot(RAINFOREST_RESIN['time'], RAINFOREST_RESIN['mid_price'])
plt.title('RAINFOREST_RESIN')
plt.xlabel('Time')
plt.ylabel('Mid Price')
# Out:
# Text(0, 0.5, 'Mid Price')

# %%
# Calculate moving average for RAINFOREST_RESIN
RAINFOREST_RESIN['MA500'] = RAINFOREST_RESIN['mid_price'].rolling(window=500).mean()

# Plot RAINFOREST_RESIN with moving average
plt.figure(figsize=(12, 6))
plt.plot(RAINFOREST_RESIN['time'], RAINFOREST_RESIN['mid_price'], label='Price', alpha=0.5)
plt.plot(RAINFOREST_RESIN['time'], RAINFOREST_RESIN['MA500'], label='500 MA', linewidth=2)
plt.title('RAINFOREST_RESIN Moving Average')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\866373341.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RAINFOREST_RESIN['MA500'] = RAINFOREST_RESIN['mid_price'].rolling(window=500).mean()

# %%
plt.plot(KELP['time'], KELP['mid_price'])
plt.title('KELP')
plt.xlabel('Time')
plt.ylabel('Mid Price')
# Out:
# Text(0, 0.5, 'Mid Price')

# %%
-0.180 * 1e6 + 1e6
# Out:
# 820000.0

# %%
plt.plot(SQUID_INK['time'], SQUID_INK['mid_price'])
plt.title('SQUID_INK')
plt.xlabel('Time')
plt.ylabel('Mid Price')
# plt.xlim(-0.1805 * 1e6, -0.179 * 1e6)
# Out:
# Text(0, 0.5, 'Mid Price')

# %%
# create a new data frame with the difference in SQUID_INK['mid_price']
SQUID_INK['difference'] = SQUID_INK['mid_price'].diff()
SQUID_INK['difference'].plot()
SQUID_INK['difference'].describe()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1673856258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SQUID_INK['difference'] = SQUID_INK['mid_price'].diff()
# count    29999.000000
# mean        -0.005350
# std          1.799888
# min       -104.500000
# 25%         -1.000000
# 50%          0.000000
# 75%          1.000000
# max         72.000000
# Name: difference, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(SQUID_INK['difference'], bins=100, edgecolor='black')
plt.title('Histogram of SQUID_INK Price Differences')
plt.xlabel('Price Difference')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.xlim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
# create a new data frame with the difference in KELP['mid_price']
KELP['difference'] = KELP['mid_price'].diff()
KELP['difference'].plot()
KELP['difference'].describe()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\2545289084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KELP['difference'] = KELP['mid_price'].diff()
# count    29999.000000
# mean         0.001117
# std          0.781493
# min         -4.000000
# 25%         -0.500000
# 50%          0.000000
# 75%          0.500000
# max         11.500000
# Name: difference, dtype: float64

# %%
# Calculate moving averages for KELP
KELP['MA50'] = KELP['mid_price'].rolling(window=50).mean()
KELP['MA1000'] = KELP['mid_price'].rolling(window=1000).mean()
KELP['MA500'] = KELP['mid_price'].rolling(window=500).mean()

# Calculate moving averages for SQUID_INK
SQUID_INK['MA50'] = SQUID_INK['mid_price'].rolling(window=50).mean()
SQUID_INK['MA1000'] = SQUID_INK['mid_price'].rolling(window=1000).mean()
SQUID_INK['MA500'] = SQUID_INK['mid_price'].rolling(window=500).mean()

# Plot KELP moving averages
plt.figure(figsize=(12, 6))
plt.plot(KELP['time'], KELP['mid_price'], label='Price', alpha=0.5)
plt.plot(KELP['time'], KELP['MA50'], label='50 MA', linewidth=2)
plt.plot(KELP['time'], KELP['MA1000'], label='1000 MA', linewidth=2)
plt.plot(KELP['time'], KELP['MA500'], label='500 MA', linewidth=2)
plt.title('KELP Moving Averages')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Plot SQUID_INK moving averages
plt.figure(figsize=(12, 6))
plt.plot(SQUID_INK['time'], SQUID_INK['mid_price'], label='Price', alpha=0.5)
plt.plot(SQUID_INK['time'], SQUID_INK['MA50'], label='50 MA', linewidth=2)
plt.plot(SQUID_INK['time'], SQUID_INK['MA1000'], label='1000 MA', linewidth=2)
plt.plot(SQUID_INK['time'], SQUID_INK['MA500'], label='500 MA', linewidth=2)
plt.title('SQUID_INK Moving Averages')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1124812989.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KELP['MA50'] = KELP['mid_price'].rolling(window=50).mean()
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1124812989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KELP['MA1000'] = KELP['mid_price'].rolling(window=1000).mean()
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1124812989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KELP['MA500'] = KELP['mid_price'].rolling(window=500).mean()
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1124812989.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SQUID_INK['MA50'] = SQUID_INK['mid_price'].rolling(window=50).mean()
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1124812989.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SQUID_INK['MA1000'] = SQUID_INK['mid_price'].rolling(window=1000).mean()
# C:\Users\akash\AppData\Local\Temp\ipykernel_11944\1124812989.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SQUID_INK['MA500'] = SQUID_INK['mid_price'].rolling(window=500).mean()

# %%
# %pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.6.0-cp310-cp310-win_amd64.whl (204.2 MB)
#      ---------------------------------------- 0.0/204.2 MB ? eta -:--:--
#      ---------------------------------------- 0.3/204.2 MB 8.6 MB/s eta 0:00:24
#      --------------------------------------- 0.9/204.2 MB 11.9 MB/s eta 0:00:18
#      --------------------------------------- 2.1/204.2 MB 16.8 MB/s eta 0:00:13
#       -------------------------------------- 3.0/204.2 MB 19.0 MB/s eta 0:00:11
#       -------------------------------------- 3.8/204.2 MB 18.6 MB/s eta 0:00:11
#      - ------------------------------------- 5.2/204.2 MB 19.7 MB/s eta 0:00:11
#      - ------------------------------------- 6.5/204.2 MB 20.7 MB/s eta 0:00:10
#      - ------------------------------------- 7.6/204.2 MB 21.2 MB/s eta 0:00:10
#      - ------------------------------------- 8.3/204.2 MB 21.2 MB/s eta 0:00:10
#      - ------------------------------------- 9.4/204.2 MB 21.5 MB/s eta 0:00:10
#      - ------------------------------------ 10.5/204.2 MB 22.6 MB/s eta 0:00:09
#      -- ----------------------------------- 11.5/204.2 MB 25.2 MB/s eta 0:00:08
#      -- ----------------------------------- 12.7/204.2 MB 23.4 MB/s eta 0:00:09
#      -- ----------------------------------- 13.6/204.2 MB 23.4 MB/s eta 0:00:09
#      -- ----------------------------------- 14.7/204.2 MB 24.2 MB/s eta 0:00:08
#      -- ----------------------------------- 15.5/204.2 MB 23.4 MB/s eta 0:00:09
#      --- ---------------------------------- 17.1/204.2 MB 24.2 MB/s eta 0:00:08
#      --- ---------------------------------- 18.2/204.2 MB 23.4 MB/s eta 0:00:08
#      --- ---------------------------------- 19.1/204.2 MB 23.4 MB/s eta 0:00:08
#      --- ---------------------------------- 20.0/204.2 MB 23.4 MB/s eta 0:00:08
#      --- ---------------------------------- 20.9/204.2 MB 23.4 MB/s eta 0:00:08
#      ---- --------------------------------- 21.6/204.2 MB 21.8 MB/s eta 0:00:09
#      ---- --------------------------------- 22.8/204.2 MB 23.4 MB/s eta 0:00:08
#      ---- --------------------------------- 23.9/204.2 MB 22.6 MB/s eta 0:00:08
#      ---- --------------------------------- 25.0/204.2 MB 22.5 MB/s eta 0:00:08
#      ---- --------------------------------- 26.4/204.2 MB 23.4 MB/s eta 0:00:08
#      ----- -------------------------------- 27.7/204.2 MB 22.6 MB/s eta 0:00:08
#      ----- -------------------------------- 28.6/204.2 MB 23.4 MB/s eta 0:00:08
using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from torch) (4.13.1)
# Collecting fsspec
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#      ---------------------------------------- 0.0/194.4 kB ? eta -:--:--
#      ---------------------------------------- 194.4/194.4 kB ? eta 0:00:00
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akash\documents\coding projects\imc-prosperity-ake-bossers\myenv\lib\site-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: mpmath, sympy, networkx, jinja2, fsspec, filelock, torch
# Successfully installed filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 sympy-1.13.1 torch-2.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim

# Prepare data for LSTM
def prepare_data(data, lookback=60):
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(data.reshape(-1, 1))
    
    X, y = [], []
    for i in range(len(scaled_data) - lookback):
        X.append(scaled_data[i:(i + lookback), 0])
        y.append(scaled_data[i + lookback, 0])
    
    return np.array(X), np.array(y), scaler

# Get KELP price data
kelp_prices = KELP['mid_price'].values

# Prepare sequences
X, y, scaler = prepare_data(kelp_prices)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Convert to PyTorch tensors
X_train = torch.FloatTensor(X_train).unsqueeze(-1)
X_test = torch.FloatTensor(X_test).unsqueeze(-1)
y_train = torch.FloatTensor(y_train)
y_test = torch.FloatTensor(y_test)

# Define LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, num_layers=2, output_size=1):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out[:, -1, :])
        out = self.fc(out)
        return out

# Initialize model
model = LSTMModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters())

# Train model
num_epochs = 50
batch_size = 32

for epoch in range(num_epochs):
    model.train()
    for i in range(0, len(X_train), batch_size):
        batch_X = X_train[i:i+batch_size]
        batch_y = y_train[i:i+batch_size]
        
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs.squeeze(), batch_y)
        loss.backward()
        optimizer.step()
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# Make predictions
model.eval()
with torch.no_grad():
    train_predict = model(X_train).numpy()
    test_predict = model(X_test).numpy()

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train_actual = scaler.inverse_transform(y_train.numpy().reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.numpy().reshape(-1, 1))

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(KELP['time'][-len(y_test_actual):], y_test_actual, label='Actual')
plt.plot(KELP['time'][-len(test_predict):], test_predict, label='Predicted')
plt.title('KELP Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate RMSE
rmse = np.sqrt(np.mean((test_predict - y_test_actual) ** 2))
print(f'Test RMSE: {rmse:.2f}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 import numpy as np
# ----> 2 from sklearn.preprocessing import MinMaxScaler
#       3 from sklearn.model_selection import train_test_split
#       4 import torch
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)
#     114     "compose",
#     115 ]
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\sklearn\utils\__init__.py:15
#      13 from . import _joblib, metadata_routing
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#      18 # Make _safe_indexing importable from here for backward compat as this particular
#      19 # helper is considered semi-private and typically very useful for third-party
#      20 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      21 # _safe_indexing was included in our public API documentation despite the leading
#      22 # `_` in its name.
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\sklearn\utils\_param_validation.py:14
#      11 from numbers import Integral, Real
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
#      17 from .validation import _is_arraylike_not_scalar
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\scipy\sparse\__init__.py:300
#     294 # Original code by Travis Oliphant.
#     295 # Modified and extended by Ed Schofield, Robert Cimrman,
#     296 # Nathan Bell, and Jake Vanderplas.
#     298 import warnings as _warnings
# --> 300 from ._base import *
#     301 from ._csr import *
#     302 from ._csc import *
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\scipy\sparse\_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis, getdtype)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\scipy\sparse\_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\scipy\_lib\_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\scipy\_lib\_array_api.py:18
#      15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#      21     numpy as np_compat,
#      22     device as xp_device,
#      23     is_numpy_namespace as is_numpy,
#      24     is_cupy_namespace as is_cupy,
#      25     is_torch_namespace as is_torch,
#      26     is_jax_namespace as is_jax,
#      27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#      30 __all__ = [
#      31     '_asarray', 'array_namespace', 'assert_almost_equal', 'assert_array_almost_equal',
#      32     'get_xp_devices',
#    (...)
#      38     'xp_take_along_axis', 'xp_unsupported_param_msg', 'xp_vector_norm',
#      39 ]
#      42 # To enable array API and strict array-like input validation
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\scipy\_lib\array_api_compat\numpy\__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\numpy\testing\__init__.py:11
#       8 from unittest import TestCase
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\numpy\testing\_private\utils.py:469
#     465         pprint.pprint(desired, msg)
#     466         raise AssertionError(msg.getvalue())
# --> 469 @np._no_nep50_warning()
#     470 def assert_almost_equal(actual, desired, decimal=7, err_msg='', verbose=True):
#     471     """
#     472     Raises an AssertionError if two items are not equal up to desired
#     473     precision.
#    (...)
#     537
#     538     """
#     539     __tracebackhide__ = True  # Hide traceback for py.test
#
# File c:\Users\akash\Documents\Coding Projects\imc-prosperity-ake-bossers\myenv\lib\site-packages\numpy\__init__.py:427, in __getattr__(attr)
#     424     import numpy.char as char
#     425     return char.chararray
# --> 427 raise AttributeError("module {!r} has no attribute "
#     428                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute '_no_nep50_warning'
